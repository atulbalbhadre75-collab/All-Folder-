# %% [markdown]
# ***welcome To Jupyter Lab***

# %% [markdown]
# *** WELCOE TO MY JUPYER LAB ***

# %%
print("Hello Atul")
# Out:
# Hello Atul

# %% [markdown]
# *** WELCOE TO MY JUPYER LAB tUTUORIALS***
